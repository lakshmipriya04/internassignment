# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train=pd.read_csv('intern-training-samples.csv',encoding='utf-16')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
# category            8046 non-null object
# description         8541 non-null object
# gender              8912 non-null object
# sub_category        10000 non-null object
# sub_sub_category    10000 non-null object
# title               7932 non-null object
# dtypes: object(6)
# memory usage: 234.4+ KB

# %%
train.head()
# Out:
#             category                                        description  \
# 0           clothing  Featured in navy oxford    Button down point c...
# 1  sports & outdoors  Every time you step on to the field, you turn ...
# 2  sports & outdoors  How to stencil a T-shirt? Print the stencil, c...
# 3           clothing  "EXCLUSIVELY OURS  Essential plush cashmere cr...
# 4        electronics  Ballistix Sport LT 16GB (2 x 8GB) 288-Pin DDR4...
#
#    gender               sub_category sub_sub_category  \
# 0    mens                       tops             None
# 1  unisex                  team shop    team clothing
# 2  unisex                  team shop    team clothing
# 3  womens                   sweaters             None
# 4     NaN  computer parts & hardware           memory
#
#                                                title
# 0                                                NaN
# 1  Miami Hurricanes adidas 2016 Football Coaches ...
# ...

# %%
train.groupby(['category','sub_category','sub_sub_category']).count()
# Out:
#                                                                             description  \
# category          sub_category            sub_sub_category
# accessories       None                    None                                       13
#                   belts & buckles         None                                       19
#                   eyeglasses              None                                        3
#                   gloves & mittens        None                                        0
#                                           gloves                                      4
#                   hair accessories        hair extensions                             1
#                   handbags                None                                        5
#                                           backpack handbags                           1
#                                           clutches & special occasion bags            2
# ...

# %%
train[train['gender'].isnull()==True]
# Out:
#                category                                        description  \
# 4           electronics  Ballistix Sport LT 16GB (2 x 8GB) 288-Pin DDR4...
# 9                   NaN  "Wild, but not over-the-top, the Softspots Wom...
# 15         toys & games  Climb up and slide down in the exciting game o...
# 16    sports & outdoors  "Make every day all about the New Orleans Sain...
# 29      health & beauty  Sage Solutions Herbal Supplement. Wisdom You C...
# 36    sports & outdoors  "This hand-painted glass nightlight is perfect...
# 41           home & pet  "Web exclusive! Decorate the walls in your hom...
# 51                  NaN                                                NaN
# 62                  NaN                                                NaN
# 73                  NaN  "Sporty knit pullover with a drawstring cowlne...
# 74                  NaN  "Italian-made loafers are stunningly sophistic...
# ...

# %%
train[train['category'].isnull()==True]
# Out:
#      category                                        description  gender  \
# 9         NaN  "Wild, but not over-the-top, the Softspots Wom...     NaN
# 17        NaN  Complete your supportive, sleek style with thi...  unisex
# 27        NaN  The Tarence Dress Sport Wedges by Anne Klein f...    None
# 31        NaN  The leaves are turning, Fall has arrived, and ...  unisex
# 35        NaN                                                NaN    None
# 39        NaN                                                NaN  unisex
# 43        NaN                                                NaN    None
# 44        NaN  Go the distance in this sporty and sophisticat...  unisex
# 51        NaN                                                NaN     NaN
# 53        NaN  The Badgy100 printer is ideally suited to your...    None
# 54        NaN  "A linen closet essential, this duvet cover is...    None
# 56        NaN  Dolce & Gabbana one-piece swimsuit in pineappl...    None
# ...
